# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# ## Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# ### Ans:
#
# ### The matplotlib is the library of python language and it is mainly used for analysis and visualization of the data
# ### Matplotlib is a plotting library available for the Python programming language as a component of NumPy, a big data numerical handling resource.
# ### below are the five plotted using pyplot module of MatPlotlib

# %% [markdown]
# ### 1. bar(x, y)
# ### 2. hist(x, y)
# ### 3. plot(x, y)
# ### 4. scatter(x, y)
# ### 5. barh(x, y)

# %% [markdown]
# ## Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# ## plot a scatter plot.
# ## import numpy as np
# ## np.random.seed(3)
# ## x = 3 + np.random.normal(0, 2, 50)
# ## y = 3 + np.random.normal(0, 2, len(x))
# ## Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# ### Ans:
# ### The scatter plot plots the data in the graph by using dots
# ### bellow is the code to plot a scatter plot

# %%
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
x
# Out:
# array([ 6.57725695,  3.8730197 ,  3.19299494, -0.72698541,  2.44522359,
#         2.29048204,  2.83451704,  1.74599865,  2.91236366,  2.04556394,
#         0.37227049,  4.76924476,  4.76263608,  6.41914613,  3.10006728,
#         2.19064517,  1.9092801 , -0.09295463,  4.96473487,  0.79786474,
#         0.62990695,  2.5887002 ,  5.97229671,  3.47343253,  0.95242972,
#         1.5740136 ,  4.25048993,  2.67897327,  1.4623273 ,  2.53993856,
#         4.49011253,  6.95222157,  0.51175334,  1.74716618,  1.39246781,
#        -1.83816635,  1.15241596,  0.95224848,  5.24795592,  2.73617153,
#        -0.24657089,  4.2933509 ,  2.28745848, -0.48628207,  1.80670072,
#         1.82281124,  1.2522354 ,  3.05942763, -1.49651554,  2.46447627])

# %%
y
# Out:
# array([ 5.02636688,  4.70559568,  5.216375  ,  5.23878131,  5.97508626,
#         0.76339863,  4.69166681, -0.72177906,  1.79422979, -0.82894409,
#         5.09629502,  5.66747564,  2.60517064,  6.54929006,  1.65054498,
#         3.30123373,  3.30589141,  0.87160945,  3.87589322,  6.87795692,
#         0.95013825,  4.79867689,  2.6909863 ,  6.53925461,  3.9675767 ,
#         4.3524328 ,  4.28632656,  3.49817341,  0.20847299,  5.78332582,
#         0.25866197,  3.47712638,  4.22815418,  1.32417545,  3.29012643,
#         5.33576457,  2.95179106,  1.22268516, -2.8314755 ,  1.05631899,
#         1.81784252,  1.96716526,  1.08000764,  3.75459047,  1.85058316,
#         2.78109133,  4.3581432 ,  1.28912566,  2.39958785,  7.31629868])

# %%
plt.title("The scatter plot")
plt.xlabel("This is xlabel")
plt.ylabel("This is ylabel")
plt.scatter(x, y, c = "red")

# %% [markdown]
# ## Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# ## Use the following data:
# ## import numpy as np
# ## For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# ## For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# ## For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# ## For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# ### Ans: The subplot function used to disply multiple plots in one single image
# ### Bellow is the code to disply the four line plot

# %%
Xline1 = np.array([0, 1, 2, 3, 4, 5])
Yline1 = np.array([0, 100, 200, 300, 400, 500])
Xline2 = np.array([0, 1, 2, 3, 4, 5])
Yline2 = np.array([50, 20, 40, 20, 60, 70])
Xline3 = np.array([0, 1, 2, 3, 4, 5])
Yline3 = np.array([10, 20, 30, 40, 50, 60])
Xline4 = np.array([0, 1, 2, 3, 4, 5])
Yline4 = np.array([200, 350, 250, 550, 450, 150])

# %%
plt.subplot(4, 1, 1)
plt.plot(Xline1, Yline1)

plt.subplot(4, 1, 2)
plt.plot(Xline2, Yline2)

plt.subplot(4, 1, 3)
plt.plot(Xline3, Yline3)

plt.subplot(4, 1, 4)
plt.plot(Xline4, Yline4)

plt.show()

# %% [markdown]
# ## Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# ## import numpy as np
# ## company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# ## profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# ### Ans:
# ### The barplot is used to represent the visualization of the data in form of bars

# %% [markdown]
# ### It shows the relationship between a numeric and a categoric variable.
# ### Each entity of the categoric variable is represented as a bar. The size of the bar represents its numeric value.

# %% [markdown]
# ### Bellow is the code for the bar plot

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.title("Horizontal Bar plot")
plt.xlabel("X Label")
plt.ylabel("Y Label")
plt.bar(company, profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.title("Horizontal Bar plot")
plt.xlabel("X Label")
plt.ylabel("Y Label")
plt.barh(company, profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# ## box1 = np.random.normal(100, 10, 200)
# ## box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# ### Ans:
# ### Box plots are used to show distributions of numeric data values, especially when you want to compare them between multiple groups. They are built to provide high-level information at a glance, offering general information about a group of data's symmetry, skew, variance, and outliers.

# %% [markdown]
# ### Bellow is the code for the box plot

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
plt.boxplot([box1, box2])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f93c4705cf0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f93c4706230>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f93c4705a50>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f93c4706770>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f93c4706a10>,
# ...
#  'means': []}
